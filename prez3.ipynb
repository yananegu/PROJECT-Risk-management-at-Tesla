# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
from arch import arch_model

# %% [markdown]
# ### Data:

# %%
data = pd.read_csv("USD_EUR.csv")
data['Ostatnio'] = data['Ostatnio'].str.replace(',', '.').astype(float)
data['Data'] = data['Data'].str.replace('.', '-')
data['Data'] = pd.to_datetime(data['Data'], format='%d-%m-%Y')
data
plt.figure(figsize=[13,7])
plt.title('Kurs walutowy USD/EUR z 21.01.2020 do 20.04.2024', color = 'yellow')
plt.plot(data['Data'], data['Ostatnio'])
plt.xlabel('Data', color = 'yellow')
plt.ylabel('Cena', color = 'yellow')
plt.xticks(color = 'yellow')
plt.yticks(color = 'yellow')
plt.grid(True)
plt.tight_layout()
plt.savefig('Kurs_walutowy_USD_EUR.png')
# Out:
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\2111729386.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Data'] = data['Data'].str.replace('.', '-')

# %%
data["d_after"] = data["Ostatnio"].shift(-1)
data = data.fillna(data["Ostatnio"].iloc[-1])
data['log_return'] = np.log(data['d_after']/data['Ostatnio'])
data = data.drop(data.index[-1])
data['log_return'].tail()

plt.figure(figsize=[13,7])
plt.title('Zwrot logarytmiczny kursu USD/EUR z 21.01.2020 do 20.04.2024', color = 'yellow')
plt.plot(data['Data'], data['log_return'])
plt.xlabel('Data', color = 'yellow' )
plt.ylabel('Zwrot logarytmiczny', color = 'yellow')
plt.xticks(color = 'yellow')
plt.yticks(color = 'yellow')
plt.grid(True)
plt.tight_layout()
plt.savefig('Zwrot_USD_EUR.png')

# %% [markdown]
# ## 1. Calculation of VaR95% and VaR99%
# ### a. parametric method with T-student distribution

# %%
params_t = stats.t.fit(data['log_return'])  
VaR_95_param = stats.t.ppf(0.05, df=params_t[0], loc=params_t[1], scale=params_t[2])
VaR_99_param = stats.t.ppf(0.01, df=params_t[0], loc=params_t[1], scale=params_t[2])
print ('Parametric method VaR95%:', VaR_95_param)
print ('Parametric method VaR99%:', VaR_99_param)

Var95 = np.zeros(len(data))
Var99 = np.zeros(len(data))
for j in range (0,len(data)):
    Var95[j] = VaR_95_param
    Var99[j] = VaR_99_param

data['VaR95%'] = Var95
data['VaR99%'] = Var99

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")
# Out:
# Parametric method VaR95%: -0.007754211978568066
# Parametric method VaR99%: -0.012273711287348926
# Liczba naruszeń VaR95%: 55
# Liczba naruszeń VaR99%: 11

# %%
# Załóżmy, że 'log_return' to Twoja seria zwrotów w DataFrame
window = 260
alphas = [0.05, 0.01]
degrees_of_freedom =  8#params_t[0]  # Liczba stopni swobody dla rozkładu t-Studenta

# Dynamicznie dostosowane okno
Var_values = []
for alpha in alphas:
    values = pd.Series(index=data['log_return'].index)
    for i in range(len(data['log_return'])):
        current_window = min(window, i + 1)  # Nie przekracza liczby dostępnych dni
        # Obliczenie średniej i odchylenia standardowego dla aktualnego okna
        windowed_data = data['log_return'][:i+1].tail(current_window)
        mean = windowed_data.mean()
        std_dev = windowed_data.std()
        # Obliczenie VaR za pomocą funkcji odwrotnej dystrybuanty rozkładu t-Studenta
        values[i] = stats.t.ppf(alpha, df=degrees_of_freedom, loc=mean, scale=std_dev)
    Var_values.append(values)

data['VaR95%'] = Var_values[0]  # Ujemny znak, jeśli VaR ma reprezentować potencjalną stratę
data['VaR99%'] = Var_values[1]  # Ujemny znak, jeśli VaR ma reprezentować potencjalną stratę

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")

plt.figure(figsize=[13,7])
plt.title('VaR95% oraz VaR 99% przy abliczeniu metodą parametrycznej', color = 'yellow')
plt.plot(data['Data'], data['log_return'])
plt.plot(data['Data'], data['VaR95%'], label = 'VaR95%', color = 'orchid')
plt.plot(data['Data'], data['VaR99%'], label = 'VaR99%', color = 'green')
plt.xlabel('Data', color = 'yellow')
plt.ylabel('Zwroty logarytmiczne', color = 'yellow')
plt.xticks(color = 'yellow')
plt.yticks(color = 'yellow')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('param.png')
# Out:
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\1663493885.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   values = pd.Series(index=data['log_return'].index)
# Liczba naruszeń VaR95%: 35
# Liczba naruszeń VaR99%: 4

# %% [markdown]
# ### b. historical method
# #### i. usual method

# %%
print("Historical usual method VaR95%:", np.quantile(data['log_return'], 0.05))
print("Historical usual method VaR99%:", np.quantile(data['log_return'], 0.01))

Var95 = np.zeros(len(data))
Var99 = np.zeros(len(data))
for j in range (0,len(data)):
    Var95[j] = np.quantile(data['log_return'], 0.05)
    Var99[j] = np.quantile(data['log_return'], 0.01)

data['VaR95%'] = Var95
data['VaR99%'] = Var99

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")
# Out:
# Historical usual method VaR95%: -0.007687015884204237
# Historical usual method VaR99%: -0.012152889911008867
# Liczba naruszeń VaR95%: 56
# Liczba naruszeń VaR99%: 12

# %%
# Załóżmy, że 'returns' to Twoja seria zwrotów w DataFrame
window = 260
alphas = [0.05, 0.01]

# Dynamicznie dostosowane okno
Var_values = []
for alpha in alphas:
    values = pd.Series(index=data['log_return'].index)
    for i in range(len(data['log_return'])):
        current_window = min(window, i + 1)  # Nie przekracza liczby dostępnych dni
        values[i] = data['log_return'][:i+1].tail(current_window).quantile(alpha)
    Var_values.append(values)


data['VaR95%'] = Var_values[0]
data['VaR99%'] = Var_values[1]

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")

plt.figure(figsize=[13,7])
plt.title('VaR95% oraz VaR 99% przy obliczeniu metodą historyczną zwykłą', color = 'mediumorchid')
plt.plot(data['Data'], data['log_return'])
plt.plot(data['Data'], data['VaR95%'], label = 'VaR95%', color = 'yellow')
plt.plot(data['Data'], data['VaR99%'], label = 'VaR99%', color = 'green')
plt.xlabel('Data', color = 'mediumorchid')
plt.ylabel('Zwroty logarytmiczne', color = 'mediumorchid')
plt.xticks(color = 'mediumorchid')
plt.yticks(color = 'mediumorchid')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('hist_zwykla.png')
# Out:
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\2063719435.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   values = pd.Series(index=data['log_return'].index)
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\2063719435.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   values = pd.Series(index=data['log_return'].index)
# Liczba naruszeń VaR95%: 60
# Liczba naruszeń VaR99%: 18

# %% [markdown]
# #### ii. ważoną
#
# linear wejghts

# %%
# Przykładowe dane
dat = data['log_return']
weights = np.linspace(1, 0, num=len(dat))  # Przykładowe wagi malejące liniowo
weights /= weights.sum()  # Normalizacja wag

# Przygotowanie DataFrame
df = pd.DataFrame({'dat': dat, 'weights': weights})

# Sortowanie danych razem z wagami
df_sorted = df.sort_values(by='dat')

# Obliczenie skumulowanych wag
df_sorted['cumulative_weight'] = df_sorted['weights'].cumsum()

# Znalezienie VaR95%
var_95 = df_sorted[df_sorted['cumulative_weight'] >= 0.05].iloc[0]['dat']
var_99 = df_sorted[df_sorted['cumulative_weight'] >= 0.01].iloc[0]['dat']

print("Ważony VaR95% wynosi:", var_95)
print("Ważony VaR99% wynosi:", var_99)

Var95 = np.zeros(len(data))
Var99 = np.zeros(len(data))
for j in range (0,len(data)):
    Var95[j] = var_95
    Var99[j] = var_99

data['VaR95%'] = Var95
data['VaR99%'] = Var99

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")
# Out:
# Ważony VaR95% wynosi: -0.007931780557856382
# Ważony VaR99% wynosi: -0.012207571588644382
# Liczba naruszeń VaR95%: 49
# Liczba naruszeń VaR99%: 11

# %%
# Dynamicznie dostosowane okno
Var_values = []
for alpha in alphas:
    values = pd.Series(index=data['log_return'].index)
    for i in range(len(data['log_return'])):
        current_window = min(window, i + 1)  # Nie przekracza liczby dostępnych dni
        windowed_data = data['log_return'][:i+1].tail(current_window)
        
        dat = windowed_data
        weights = np.linspace(1, 0, num=len(dat))  # Przykładowe wagi malejące liniowo
        weights /= weights.sum()  # Normalizacja wag

        # Przygotowanie DataFrame
        df = pd.DataFrame({'dat': dat, 'weights': weights})

        # Sortowanie danych razem z wagami
        df_sorted = df.sort_values(by='dat')

        # Obliczenie skumulowanych wag
        df_sorted['cumulative_weight'] = df_sorted['weights'].cumsum()
        
        values[i] = df_sorted[df_sorted['cumulative_weight'] >= alpha].iloc[0]['dat']
    Var_values.append(values)

data['VaR95%'] = Var_values[0]  # Ujemny znak, jeśli VaR ma reprezentować potencjalną stratę
data['VaR99%'] = Var_values[1]  # Ujemny znak, jeśli VaR ma reprezentować potencjalną stratę

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")

plt.figure(figsize=[13,7])
plt.title('VaR95% oraz VaR 99% przy obliczeniu metodą historyczną ważoną', color = 'mediumseagreen')
plt.plot(data['Data'], data['log_return'])
plt.plot(data['Data'], data['VaR95%'], label = 'VaR95%', color = 'palevioletred')
plt.plot(data['Data'], data['VaR99%'], label = 'VaR99%', color = 'green')
plt.xlabel('Data', color = 'mediumseagreen')
plt.ylabel('Zwroty logarytmiczne', color = 'mediumseagreen')
plt.xticks(color = 'mediumseagreen')
plt.yticks(color = 'mediumseagreen')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('hist_wag.png')
# Out:
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\171969955.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   values = pd.Series(index=data['log_return'].index)
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\171969955.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   values = pd.Series(index=data['log_return'].index)
# Liczba naruszeń VaR95%: 58
# Liczba naruszeń VaR99%: 18

# %% [markdown]
# exponential weighs

# %% [markdown]
# #### iii. using GARCH series filtering

# %%
# Przygotowanie danych (załóżmy, że 'returns' to twoje dane zwrotów)
returns = data['log_return']*100

# Lista do przechowywania wyników
results = []

# Test różnych kombinacji p i q
for p in range(1, 6):  # Testuj p od 1 do 3
    for q in range(1, 6):  # Testuj q od 1 do 3
        model = arch_model(returns, p=p, q=q, rescale=False)
        model_fit = model.fit(disp='off')
        results.append({
            'p': p,
            'q': q,
            'aic': model_fit.aic,
            'bic': model_fit.bic
        })

# Konwersja wyników na DataFrame
results_df = pd.DataFrame(results)

# Znalezienie modelu z najniższym AIC
best_model_aic = results_df.loc[results_df['aic'].idxmin()]
print("Najlepszy model ", best_model_aic)
# Out:
# Najlepszy model  p         1.000000
# q         1.000000
# aic    1410.905000
# bic    1430.946248
# Name: 0, dtype: float64

# %%
# Załóżmy, że 'data' to Twój DataFrame
window = 260
min_window = 20  # minimalna liczba danych do rozpoczęcia obliczeń
alphas = [0.05, 0.01]
Var_values = []

for alpha in alphas:
    values = pd.Series(index=data['log_return'].index)
    for i in range(len(data['log_return'])):
        # Ajustuj okno, aby zawsze korzystać z dostępnych danych
        current_window = max(min_window, min(window, i + 1))
        X = data['log_return'].iloc[max(0, i-current_window+1):i+1]*100
        if len(X.dropna()) >= min_window:
            try:
                am = arch_model(X.dropna(), mean='Zero', vol='Garch', p=1, o=0, q=1, dist='Normal', rescale=False)
                res = am.fit(update_freq=0, disp='off')
                forecast = res.forecast(horizon=1)
                s2 = forecast.variance.values[-1, -1]
                VaR_garch = -np.sqrt(s2) * stats.norm.ppf(1-alpha)
                values[i] = VaR_garch
            except Exception as e:
                print(f"Error at index {i}: {e}")
                values[i] = np.nan  # Handle errors or convergence issues
        else:
            values[i] = np.nan  # Not enough data to fit model
    Var_values.append(values/100)

data['VaR95%'] = Var_values[0].fillna(method='ffill')  # Fill NaN with forward fill if needed
data['VaR99%'] = Var_values[1].fillna(method='ffill')

mean_VaR95 = data['VaR95%'].mean()
mean_VaR99 = data['VaR99%'].mean()

print(f"Średni VaR95%: {mean_VaR95}")
print(f"Średni VaR99%: {mean_VaR99}")

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")

plt.figure(figsize=[13,7])
plt.title('VaR95% oraz VaR 99% przy obliczeniu metodą historyczną z filtrowaniem szeregiem GARCH', color = 'white')
plt.plot(data['Data'], data['log_return'])
plt.plot(data['Data'], data['VaR95%'], label = 'VaR95%', color = 'orchid')
plt.plot(data['Data'], data['VaR99%'], label = 'VaR99%', color = 'green')
plt.xlabel('Data', color = 'white')
plt.ylabel('Zwroty logarytmiczne', color = 'white')
plt.xticks(color = 'white')
plt.yticks(color = 'white')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('hist_GARCH.png')
# Out:
# Error at index 19: 'Series' object is not callable
# Error at index 20: 'Series' object is not callable
# Error at index 21: 'Series' object is not callable
# Error at index 22: 'Series' object is not callable
# Error at index 23: 'Series' object is not callable
# Error at index 24: 'Series' object is not callable
# Error at index 25: 'Series' object is not callable
# Error at index 26: 'Series' object is not callable
# Error at index 27: 'Series' object is not callable
# Error at index 28: 'Series' object is not callable
# Error at index 29: 'Series' object is not callable
# Error at index 30: 'Series' object is not callable
# Error at index 31: 'Series' object is not callable
# Error at index 32: 'Series' object is not callable
# Error at index 33: 'Series' object is not callable
# Error at index 34: 'Series' object is not callable
# Error at index 35: 'Series' object is not callable
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\3124971848.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   values = pd.Series(index=data['log_return'].index)
# Error at index 36: 'Series' object is not callable
# Error at index 37: 'Series' object is not callable
# Error at index 38: 'Series' object is not callable
# Error at index 39: 'Series' object is not callable
# Error at index 40: 'Series' object is not callable
# Error at index 41: 'Series' object is not callable
# Error at index 42: 'Series' object is not callable
# Error at index 43: 'Series' object is not callable
# Error at index 44: 'Series' object is not callable
# Error at index 45: 'Series' object is not callable
# Error at index 46: 'Series' object is not callable
# Error at index 47: 'Series' object is not callable
# Error at index 48: 'Series' object is not callable
# Error at index 49: 'Series' object is not callable
# Error at index 50: 'Series' object is not callable
# Error at index 51: 'Series' object is not callable
# Error at index 52: 'Series' object is not callable
# Error at index 53: 'Series' object is not callable
# Error at index 54: 'Series' object is not callable
# Error at index 55: 'Series' object is not callable
# Error at index 56: 'Series' object is not callable
# Error at index 57: 'Series' object is not callable
# Error at index 58: 'Series' object is not callable
# Error at index 59: 'Series' object is not callable
# Error at index 60: 'Series' object is not callable
# Error at index 61: 'Series' object is not callable
# Error at index 62: 'Series' object is not callable
# Error at index 63: 'Series' object is not callable
# Error at index 64: 'Series' object is not callable
# Error at index 65: 'Series' object is not callable
# Error at index 66: 'Series' object is not callable
# Error at index 67: 'Series' object is not callable
# Error at index 68: 'Series' object is not callable
# Error at index 69: 'Series' object is not callable
# Error at index 70: 'Series' object is not callable
# Error at index 71: 'Series' object is not callable
# Error at index 72: 'Series' object is not callable
# Error at index 73: 'Series' object is not callable
# Error at index 74: 'Series' object is not callable
# Error at index 75: 'Series' object is not callable
# Error at index 76: 'Series' object is not callable
# Error at index 77: 'Series' object is not callable
# Error at index 78: 'Series' object is not callable
# Error at index 79: 'Series' object is not callable
# Error at index 80: 'Series' object is not callable
# Error at index 81: 'Series' object is not callable
# Error at index 82: 'Series' object is not callable
# Error at index 83: 'Series' object is not callable
# Error at index 84: 'Series' object is not callable
# Error at index 85: 'Series' object is not callable
# Error at index 86: 'Series' object is not callable
# Error at index 87: 'Series' object is not callable
# Error at index 88: 'Series' object is not callable
# Error at index 89: 'Series' object is not callable
# Error at index 90: 'Series' object is not callable
# Error at index 91: 'Series' object is not callable
# Error at index 92: 'Series' object is not callable
# Error at index 93: 'Series' object is not callable
# Error at index 94: 'Series' object is not callable
# Error at index 95: 'Series' object is not callable
# Error at index 96: 'Series' object is not callable
# Error at index 97: 'Series' object is not callable
# Error at index 98: 'Series' object is not callable
# Error at index 99: 'Series' object is not callable
# Error at index 100: 'Series' object is not callable
# Error at index 101: 'Series' object is not callable
# Error at index 102: 'Series' object is not callable
# Error at index 103: 'Series' object is not callable
# Error at index 104: 'Series' object is not callable
# Error at index 105: 'Series' object is not callable
# Error at index 106: 'Series' object is not callable
# Error at index 107: 'Series' object is not callable
# Error at index 108: 'Series' object is not callable
# Error at index 109: 'Series' object is not callable
# Error at index 110: 'Series' object is not callable
# Error at index 111: 'Series' object is not callable
# Error at index 112: 'Series' object is not callable
# Error at index 113: 'Series' object is not callable
# Error at index 114: 'Series' object is not callable
# Error at index 115: 'Series' object is not callable
# Error at index 116: 'Series' object is not callable
# Error at index 117: 'Series' object is not callable
# Error at index 118: 'Series' object is not callable
# Error at index 119: 'Series' object is not callable
# Error at index 120: 'Series' object is not callable
# Error at index 121: 'Series' object is not callable
# Error at index 122: 'Series' object is not callable
# Error at index 123: 'Series' object is not callable
# Error at index 124: 'Series' object is not callable
# Error at index 125: 'Series' object is not callable
# Error at index 126: 'Series' object is not callable
# Error at index 127: 'Series' object is not callable
# Error at index 128: 'Series' object is not callable
# Error at index 129: 'Series' object is not callable
# Error at index 130: 'Series' object is not callable
# Error at index 131: 'Series' object is not callable
# Error at index 132: 'Series' object is not callable
# Error at index 133: 'Series' object is not callable
# Error at index 134: 'Series' object is not callable
# Error at index 135: 'Series' object is not callable
# Error at index 136: 'Series' object is not callable
# Error at index 137: 'Series' object is not callable
# Error at index 138: 'Series' object is not callable
# Error at index 139: 'Series' object is not callable
# Error at index 140: 'Series' object is not callable
# Error at index 141: 'Series' object is not callable
# Error at index 142: 'Series' object is not callable
# Error at index 143: 'Series' object is not callable
# Error at index 144: 'Series' object is not callable
# Error at index 145: 'Series' object is not callable
# Error at index 146: 'Series' object is not callable
# Error at index 147: 'Series' object is not callable
# Error at index 148: 'Series' object is not callable
# Error at index 149: 'Series' object is not callable
# Error at index 150: 'Series' object is not callable
# Error at index 151: 'Series' object is not callable
# Error at index 152: 'Series' object is not callable
# Error at index 153: 'Series' object is not callable
# Error at index 154: 'Series' object is not callable
# Error at index 155: 'Series' object is not callable
# Error at index 156: 'Series' object is not callable
# Error at index 157: 'Series' object is not callable
# Error at index 158: 'Series' object is not callable
# Error at index 159: 'Series' object is not callable
# Error at index 160: 'Series' object is not callable
# Error at index 161: 'Series' object is not callable
# Error at index 162: 'Series' object is not callable
# Error at index 163: 'Series' object is not callable
# Error at index 164: 'Series' object is not callable
# Error at index 165: 'Series' object is not callable
# Error at index 166: 'Series' object is not callable
# Error at index 167: 'Series' object is not callable
# Error at index 168: 'Series' object is not callable
# Error at index 169: 'Series' object is not callable
# Error at index 170: 'Series' object is not callable
# Error at index 171: 'Series' object is not callable
# Error at index 172: 'Series' object is not callable
# Error at index 173: 'Series' object is not callable
# Error at index 174: 'Series' object is not callable
# Error at index 175: 'Series' object is not callable
# Error at index 176: 'Series' object is not callable
# Error at index 177: 'Series' object is not callable
# Error at index 178: 'Series' object is not callable
# Error at index 179: 'Series' object is not callable
# Error at index 180: 'Series' object is not callable
# Error at index 181: 'Series' object is not callable
# Error at index 182: 'Series' object is not callable
# Error at index 183: 'Series' object is not callable
# Error at index 184: 'Series' object is not callable
# Error at index 185: 'Series' object is not callable
# Error at index 186: 'Series' object is not callable
# Error at index 187: 'Series' object is not callable
# Error at index 188: 'Series' object is not callable
# Error at index 189: 'Series' object is not callable
# Error at index 190: 'Series' object is not callable
# Error at index 191: 'Series' object is not callable
# Error at index 192: 'Series' object is not callable
# Error at index 193: 'Series' object is not callable
# Error at index 194: 'Series' object is not callable
# Error at index 195: 'Series' object is not callable
# Error at index 196: 'Series' object is not callable
# Error at index 197: 'Series' object is not callable
# Error at index 198: 'Series' object is not callable
# Error at index 199: 'Series' object is not callable
# Error at index 200: 'Series' object is not callable
# Error at index 201: 'Series' object is not callable
# Error at index 202: 'Series' object is not callable
# Error at index 203: 'Series' object is not callable
# Error at index 204: 'Series' object is not callable
# Error at index 205: 'Series' object is not callable
# Error at index 206: 'Series' object is not callable
# Error at index 207: 'Series' object is not callable
# Error at index 208: 'Series' object is not callable
# Error at index 209: 'Series' object is not callable
# Error at index 210: 'Series' object is not callable
# Error at index 211: 'Series' object is not callable
# Error at index 212: 'Series' object is not callable
# Error at index 213: 'Series' object is not callable
# Error at index 214: 'Series' object is not callable
# Error at index 215: 'Series' object is not callable
# Error at index 216: 'Series' object is not callable
# Error at index 217: 'Series' object is not callable
# Error at index 218: 'Series' object is not callable
# Error at index 219: 'Series' object is not callable
# Error at index 220: 'Series' object is not callable
# Error at index 221: 'Series' object is not callable
# Error at index 222: 'Series' object is not callable
# Error at index 223: 'Series' object is not callable
# Error at index 224: 'Series' object is not callable
# Error at index 225: 'Series' object is not callable
# Error at index 226: 'Series' object is not callable
# Error at index 227: 'Series' object is not callable
# Error at index 228: 'Series' object is not callable
# Error at index 229: 'Series' object is not callable
# Error at index 230: 'Series' object is not callable
# Error at index 231: 'Series' object is not callable
# Error at index 232: 'Series' object is not callable
# Error at index 233: 'Series' object is not callable
# Error at index 234: 'Series' object is not callable
# Error at index 235: 'Series' object is not callable
# Error at index 236: 'Series' object is not callable
# Error at index 237: 'Series' object is not callable
# Error at index 238: 'Series' object is not callable
# Error at index 239: 'Series' object is not callable
# Error at index 240: 'Series' object is not callable
# Error at index 241: 'Series' object is not callable
# Error at index 242: 'Series' object is not callable
# Error at index 243: 'Series' object is not callable
# Error at index 244: 'Series' object is not callable
# Error at index 245: 'Series' object is not callable
# Error at index 246: 'Series' object is not callable
# Error at index 247: 'Series' object is not callable
# Error at index 248: 'Series' object is not callable
# Error at index 249: 'Series' object is not callable
# Error at index 250: 'Series' object is not callable
# Error at index 251: 'Series' object is not callable
# Error at index 252: 'Series' object is not callable
# Error at index 253: 'Series' object is not callable
# Error at index 254: 'Series' object is not callable
# Error at index 255: 'Series' object is not callable
# Error at index 256: 'Series' object is not callable
# Error at index 257: 'Series' object is not callable
# Error at index 258: 'Series' object is not callable
# Error at index 259: 'Series' object is not callable
# Error at index 260: 'Series' object is not callable
# Error at index 261: 'Series' object is not callable
# Error at index 262: 'Series' object is not callable
# Error at index 263: 'Series' object is not callable
# Error at index 264: 'Series' object is not callable
# Error at index 265: 'Series' object is not callable
# Error at index 266: 'Series' object is not callable
# Error at index 267: 'Series' object is not callable
# Error at index 268: 'Series' object is not callable
# Error at index 269: 'Series' object is not callable
# Error at index 270: 'Series' object is not callable
# Error at index 271: 'Series' object is not callable
# Error at index 272: 'Series' object is not callable
# Error at index 273: 'Series' object is not callable
# Error at index 274: 'Series' object is not callable
# Error at index 275: 'Series' object is not callable
# Error at index 276: 'Series' object is not callable
# Error at index 277: 'Series' object is not callable
# Error at index 278: 'Series' object is not callable
# Error at index 279: 'Series' object is not callable
# Error at index 280: 'Series' object is not callable
# Error at index 281: 'Series' object is not callable
# Error at index 282: 'Series' object is not callable
# Error at index 283: 'Series' object is not callable
# Error at index 284: 'Series' object is not callable
# Error at index 285: 'Series' object is not callable
# Error at index 286: 'Series' object is not callable
# Error at index 287: 'Series' object is not callable
# Error at index 288: 'Series' object is not callable
# Error at index 289: 'Series' object is not callable
# Error at index 290: 'Series' object is not callable
# Error at index 291: 'Series' object is not callable
# Error at index 292: 'Series' object is not callable
# Error at index 293: 'Series' object is not callable
# Error at index 294: 'Series' object is not callable
# Error at index 295: 'Series' object is not callable
# Error at index 296: 'Series' object is not callable
# Error at index 297: 'Series' object is not callable
# Error at index 298: 'Series' object is not callable
# Error at index 299: 'Series' object is not callable
# Error at index 300: 'Series' object is not callable
# Error at index 301: 'Series' object is not callable
# Error at index 302: 'Series' object is not callable
# Error at index 303: 'Series' object is not callable
# Error at index 304: 'Series' object is not callable
# Error at index 305: 'Series' object is not callable
# Error at index 306: 'Series' object is not callable
# Error at index 307: 'Series' object is not callable
# Error at index 308: 'Series' object is not callable
# Error at index 309: 'Series' object is not callable
# Error at index 310: 'Series' object is not callable
# Error at index 311: 'Series' object is not callable
# Error at index 312: 'Series' object is not callable
# Error at index 313: 'Series' object is not callable
# Error at index 314: 'Series' object is not callable
# Error at index 315: 'Series' object is not callable
# Error at index 316: 'Series' object is not callable
# Error at index 317: 'Series' object is not callable
# Error at index 318: 'Series' object is not callable
# Error at index 319: 'Series' object is not callable
# Error at index 320: 'Series' object is not callable
# Error at index 321: 'Series' object is not callable
# Error at index 322: 'Series' object is not callable
# Error at index 323: 'Series' object is not callable
# Error at index 324: 'Series' object is not callable
# Error at index 325: 'Series' object is not callable
# Error at index 326: 'Series' object is not callable
# Error at index 327: 'Series' object is not callable
# Error at index 328: 'Series' object is not callable
# Error at index 329: 'Series' object is not callable
# Error at index 330: 'Series' object is not callable
# Error at index 331: 'Series' object is not callable
# Error at index 332: 'Series' object is not callable
# Error at index 333: 'Series' object is not callable
# Error at index 334: 'Series' object is not callable
# Error at index 335: 'Series' object is not callable
# Error at index 336: 'Series' object is not callable
# Error at index 337: 'Series' object is not callable
# Error at index 338: 'Series' object is not callable
# Error at index 339: 'Series' object is not callable
# Error at index 340: 'Series' object is not callable
# Error at index 341: 'Series' object is not callable
# Error at index 342: 'Series' object is not callable
# Error at index 343: 'Series' object is not callable
# Error at index 344: 'Series' object is not callable
# Error at index 345: 'Series' object is not callable
# Error at index 346: 'Series' object is not callable
# Error at index 347: 'Series' object is not callable
# Error at index 348: 'Series' object is not callable
# Error at index 349: 'Series' object is not callable
# Error at index 350: 'Series' object is not callable
# Error at index 351: 'Series' object is not callable
# Error at index 352: 'Series' object is not callable
# Error at index 353: 'Series' object is not callable
# Error at index 354: 'Series' object is not callable
# Error at index 355: 'Series' object is not callable
# Error at index 356: 'Series' object is not callable
# Error at index 357: 'Series' object is not callable
# Error at index 358: 'Series' object is not callable
# Error at index 359: 'Series' object is not callable
# Error at index 360: 'Series' object is not callable
# Error at index 361: 'Series' object is not callable
# Error at index 362: 'Series' object is not callable
# Error at index 363: 'Series' object is not callable
# Error at index 364: 'Series' object is not callable
# Error at index 365: 'Series' object is not callable
# Error at index 366: 'Series' object is not callable
# Error at index 367: 'Series' object is not callable
# Error at index 368: 'Series' object is not callable
# Error at index 369: 'Series' object is not callable
# Error at index 370: 'Series' object is not callable
# Error at index 371: 'Series' object is not callable
# Error at index 372: 'Series' object is not callable
# Error at index 373: 'Series' object is not callable
# Error at index 374: 'Series' object is not callable
# Error at index 375: 'Series' object is not callable
# Error at index 376: 'Series' object is not callable
# Error at index 377: 'Series' object is not callable
# Error at index 378: 'Series' object is not callable
# Error at index 379: 'Series' object is not callable
# Error at index 380: 'Series' object is not callable
# Error at index 381: 'Series' object is not callable
# Error at index 382: 'Series' object is not callable
# Error at index 383: 'Series' object is not callable
# Error at index 384: 'Series' object is not callable
# Error at index 385: 'Series' object is not callable
# Error at index 386: 'Series' object is not callable
# Error at index 387: 'Series' object is not callable
# Error at index 388: 'Series' object is not callable
# Error at index 389: 'Series' object is not callable
# Error at index 390: 'Series' object is not callable
# Error at index 391: 'Series' object is not callable
# Error at index 392: 'Series' object is not callable
# Error at index 393: 'Series' object is not callable
# Error at index 394: 'Series' object is not callable
# Error at index 395: 'Series' object is not callable
# Error at index 396: 'Series' object is not callable
# Error at index 397: 'Series' object is not callable
# Error at index 398: 'Series' object is not callable
# Error at index 399: 'Series' object is not callable
# Error at index 400: 'Series' object is not callable
# Error at index 401: 'Series' object is not callable
# Error at index 402: 'Series' object is not callable
# Error at index 403: 'Series' object is not callable
# Error at index 404: 'Series' object is not callable
# Error at index 405: 'Series' object is not callable
# Error at index 406: 'Series' object is not callable
# Error at index 407: 'Series' object is not callable
# Error at index 408: 'Series' object is not callable
# Error at index 409: 'Series' object is not callable
# Error at index 410: 'Series' object is not callable
# Error at index 411: 'Series' object is not callable
# Error at index 412: 'Series' object is not callable
# Error at index 413: 'Series' object is not callable
# Error at index 414: 'Series' object is not callable
# Error at index 415: 'Series' object is not callable
# Error at index 416: 'Series' object is not callable
# Error at index 417: 'Series' object is not callable
# Error at index 418: 'Series' object is not callable
# Error at index 419: 'Series' object is not callable
# Error at index 420: 'Series' object is not callable
# Error at index 421: 'Series' object is not callable
# Error at index 422: 'Series' object is not callable
# Error at index 423: 'Series' object is not callable
# Error at index 424: 'Series' object is not callable
# Error at index 425: 'Series' object is not callable
# Error at index 426: 'Series' object is not callable
# Error at index 427: 'Series' object is not callable
# Error at index 428: 'Series' object is not callable
# Error at index 429: 'Series' object is not callable
# Error at index 430: 'Series' object is not callable
# Error at index 431: 'Series' object is not callable
# Error at index 432: 'Series' object is not callable
# Error at index 433: 'Series' object is not callable
# Error at index 434: 'Series' object is not callable
# Error at index 435: 'Series' object is not callable
# Error at index 436: 'Series' object is not callable
# Error at index 437: 'Series' object is not callable
# Error at index 438: 'Series' object is not callable
# Error at index 439: 'Series' object is not callable
# Error at index 440: 'Series' object is not callable
# Error at index 441: 'Series' object is not callable
# Error at index 442: 'Series' object is not callable
# Error at index 443: 'Series' object is not callable
# Error at index 444: 'Series' object is not callable
# Error at index 445: 'Series' object is not callable
# Error at index 446: 'Series' object is not callable
# Error at index 447: 'Series' object is not callable
# Error at index 448: 'Series' object is not callable
# Error at index 449: 'Series' object is not callable
# Error at index 450: 'Series' object is not callable
# Error at index 451: 'Series' object is not callable
# Error at index 452: 'Series' object is not callable
# Error at index 453: 'Series' object is not callable
# Error at index 454: 'Series' object is not callable
# Error at index 455: 'Series' object is not callable
# Error at index 456: 'Series' object is not callable
# Error at index 457: 'Series' object is not callable
# Error at index 458: 'Series' object is not callable
# Error at index 459: 'Series' object is not callable
# Error at index 460: 'Series' object is not callable
# Error at index 461: 'Series' object is not callable
# Error at index 462: 'Series' object is not callable
# Error at index 463: 'Series' object is not callable
# Error at index 464: 'Series' object is not callable
# Error at index 465: 'Series' object is not callable
# Error at index 466: 'Series' object is not callable
# Error at index 467: 'Series' object is not callable
# Error at index 468: 'Series' object is not callable
# Error at index 469: 'Series' object is not callable
# Error at index 470: 'Series' object is not callable
# Error at index 471: 'Series' object is not callable
# Error at index 472: 'Series' object is not callable
# Error at index 473: 'Series' object is not callable
# Error at index 474: 'Series' object is not callable
# Error at index 475: 'Series' object is not callable
# Error at index 476: 'Series' object is not callable
# Error at index 477: 'Series' object is not callable
# Error at index 478: 'Series' object is not callable
# Error at index 479: 'Series' object is not callable
# Error at index 480: 'Series' object is not callable
# Error at index 481: 'Series' object is not callable
# Error at index 482: 'Series' object is not callable
# Error at index 483: 'Series' object is not callable
# Error at index 484: 'Series' object is not callable
# Error at index 485: 'Series' object is not callable
# Error at index 486: 'Series' object is not callable
# Error at index 487: 'Series' object is not callable
# Error at index 488: 'Series' object is not callable
# Error at index 489: 'Series' object is not callable
# Error at index 490: 'Series' object is not callable
# Error at index 491: 'Series' object is not callable
# Error at index 492: 'Series' object is not callable
# Error at index 493: 'Series' object is not callable
# Error at index 494: 'Series' object is not callable
# Error at index 495: 'Series' object is not callable
# Error at index 496: 'Series' object is not callable
# Error at index 497: 'Series' object is not callable
# Error at index 498: 'Series' object is not callable
# Error at index 499: 'Series' object is not callable
# Error at index 500: 'Series' object is not callable
# Error at index 501: 'Series' object is not callable
# Error at index 502: 'Series' object is not callable
# Error at index 503: 'Series' object is not callable
# Error at index 504: 'Series' object is not callable
# Error at index 505: 'Series' object is not callable
# Error at index 506: 'Series' object is not callable
# Error at index 507: 'Series' object is not callable
# Error at index 508: 'Series' object is not callable
# Error at index 509: 'Series' object is not callable
# Error at index 510: 'Series' object is not callable
# Error at index 511: 'Series' object is not callable
# Error at index 512: 'Series' object is not callable
# Error at index 513: 'Series' object is not callable
# Error at index 514: 'Series' object is not callable
# Error at index 515: 'Series' object is not callable
# Error at index 516: 'Series' object is not callable
# Error at index 517: 'Series' object is not callable
# Error at index 518: 'Series' object is not callable
# Error at index 519: 'Series' object is not callable
# Error at index 520: 'Series' object is not callable
# Error at index 521: 'Series' object is not callable
# Error at index 522: 'Series' object is not callable
# Error at index 523: 'Series' object is not callable
# Error at index 524: 'Series' object is not callable
# Error at index 525: 'Series' object is not callable
# Error at index 526: 'Series' object is not callable
# Error at index 527: 'Series' object is not callable
# Error at index 528: 'Series' object is not callable
# Error at index 529: 'Series' object is not callable
# Error at index 530: 'Series' object is not callable
# Error at index 531: 'Series' object is not callable
# Error at index 532: 'Series' object is not callable
# Error at index 533: 'Series' object is not callable
# Error at index 534: 'Series' object is not callable
# Error at index 535: 'Series' object is not callable
# Error at index 536: 'Series' object is not callable
# Error at index 537: 'Series' object is not callable
# Error at index 538: 'Series' object is not callable
# Error at index 539: 'Series' object is not callable
# Error at index 540: 'Series' object is not callable
# Error at index 541: 'Series' object is not callable
# Error at index 542: 'Series' object is not callable
# Error at index 543: 'Series' object is not callable
# Error at index 544: 'Series' object is not callable
# Error at index 545: 'Series' object is not callable
# Error at index 546: 'Series' object is not callable
# Error at index 547: 'Series' object is not callable
# Error at index 548: 'Series' object is not callable
# Error at index 549: 'Series' object is not callable
# Error at index 550: 'Series' object is not callable
# Error at index 551: 'Series' object is not callable
# Error at index 552: 'Series' object is not callable
# Error at index 553: 'Series' object is not callable
# Error at index 554: 'Series' object is not callable
# Error at index 555: 'Series' object is not callable
# Error at index 556: 'Series' object is not callable
# Error at index 557: 'Series' object is not callable
# Error at index 558: 'Series' object is not callable
# Error at index 559: 'Series' object is not callable
# Error at index 560: 'Series' object is not callable
# Error at index 561: 'Series' object is not callable
# Error at index 562: 'Series' object is not callable
# Error at index 563: 'Series' object is not callable
# Error at index 564: 'Series' object is not callable
# Error at index 565: 'Series' object is not callable
# Error at index 566: 'Series' object is not callable
# Error at index 567: 'Series' object is not callable
# Error at index 568: 'Series' object is not callable
# Error at index 569: 'Series' object is not callable
# Error at index 570: 'Series' object is not callable
# Error at index 571: 'Series' object is not callable
# Error at index 572: 'Series' object is not callable
# Error at index 573: 'Series' object is not callable
# Error at index 574: 'Series' object is not callable
# Error at index 575: 'Series' object is not callable
# Error at index 576: 'Series' object is not callable
# Error at index 577: 'Series' object is not callable
# Error at index 578: 'Series' object is not callable
# Error at index 579: 'Series' object is not callable
# Error at index 580: 'Series' object is not callable
# Error at index 581: 'Series' object is not callable
# Error at index 582: 'Series' object is not callable
# Error at index 583: 'Series' object is not callable
# Error at index 584: 'Series' object is not callable
# Error at index 585: 'Series' object is not callable
# Error at index 586: 'Series' object is not callable
# Error at index 587: 'Series' object is not callable
# Error at index 588: 'Series' object is not callable
# Error at index 589: 'Series' object is not callable
# Error at index 590: 'Series' object is not callable
# Error at index 591: 'Series' object is not callable
# Error at index 592: 'Series' object is not callable
# Error at index 593: 'Series' object is not callable
# Error at index 594: 'Series' object is not callable
# Error at index 595: 'Series' object is not callable
# Error at index 596: 'Series' object is not callable
# Error at index 597: 'Series' object is not callable
# Error at index 598: 'Series' object is not callable
# Error at index 599: 'Series' object is not callable
# Error at index 600: 'Series' object is not callable
# Error at index 601: 'Series' object is not callable
# Error at index 602: 'Series' object is not callable
# Error at index 603: 'Series' object is not callable
# Error at index 604: 'Series' object is not callable
# Error at index 605: 'Series' object is not callable
# Error at index 606: 'Series' object is not callable
# Error at index 607: 'Series' object is not callable
# Error at index 608: 'Series' object is not callable
# Error at index 609: 'Series' object is not callable
# Error at index 610: 'Series' object is not callable
# Error at index 611: 'Series' object is not callable
# Error at index 612: 'Series' object is not callable
# Error at index 613: 'Series' object is not callable
# Error at index 614: 'Series' object is not callable
# Error at index 615: 'Series' object is not callable
# Error at index 616: 'Series' object is not callable
# Error at index 617: 'Series' object is not callable
# Error at index 618: 'Series' object is not callable
# Error at index 619: 'Series' object is not callable
# Error at index 620: 'Series' object is not callable
# Error at index 621: 'Series' object is not callable
# Error at index 622: 'Series' object is not callable
# Error at index 623: 'Series' object is not callable
# Error at index 624: 'Series' object is not callable
# Error at index 625: 'Series' object is not callable
# Error at index 626: 'Series' object is not callable
# Error at index 627: 'Series' object is not callable
# Error at index 628: 'Series' object is not callable
# Error at index 629: 'Series' object is not callable
# Error at index 630: 'Series' object is not callable
# Error at index 631: 'Series' object is not callable
# Error at index 632: 'Series' object is not callable
# Error at index 633: 'Series' object is not callable
# Error at index 634: 'Series' object is not callable
# Error at index 635: 'Series' object is not callable
# Error at index 636: 'Series' object is not callable
# Error at index 637: 'Series' object is not callable
# Error at index 638: 'Series' object is not callable
# Error at index 639: 'Series' object is not callable
# Error at index 640: 'Series' object is not callable
# Error at index 641: 'Series' object is not callable
# Error at index 642: 'Series' object is not callable
# Error at index 643: 'Series' object is not callable
# Error at index 644: 'Series' object is not callable
# Error at index 645: 'Series' object is not callable
# Error at index 646: 'Series' object is not callable
# Error at index 647: 'Series' object is not callable
# Error at index 648: 'Series' object is not callable
# Error at index 649: 'Series' object is not callable
# Error at index 650: 'Series' object is not callable
# Error at index 651: 'Series' object is not callable
# Error at index 652: 'Series' object is not callable
# Error at index 653: 'Series' object is not callable
# Error at index 654: 'Series' object is not callable
# Error at index 655: 'Series' object is not callable
# Error at index 656: 'Series' object is not callable
# Error at index 657: 'Series' object is not callable
# Error at index 658: 'Series' object is not callable
# Error at index 659: 'Series' object is not callable
# Error at index 660: 'Series' object is not callable
# Error at index 661: 'Series' object is not callable
# Error at index 662: 'Series' object is not callable
# Error at index 663: 'Series' object is not callable
# Error at index 664: 'Series' object is not callable
# Error at index 665: 'Series' object is not callable
# Error at index 666: 'Series' object is not callable
# Error at index 667: 'Series' object is not callable
# Error at index 668: 'Series' object is not callable
# Error at index 669: 'Series' object is not callable
# Error at index 670: 'Series' object is not callable
# Error at index 671: 'Series' object is not callable
# Error at index 672: 'Series' object is not callable
# Error at index 673: 'Series' object is not callable
# Error at index 674: 'Series' object is not callable
# Error at index 675: 'Series' object is not callable
# Error at index 676: 'Series' object is not callable
# Error at index 677: 'Series' object is not callable
# Error at index 678: 'Series' object is not callable
# Error at index 679: 'Series' object is not callable
# Error at index 680: 'Series' object is not callable
# Error at index 681: 'Series' object is not callable
# Error at index 682: 'Series' object is not callable
# Error at index 683: 'Series' object is not callable
# Error at index 684: 'Series' object is not callable
# Error at index 685: 'Series' object is not callable
# Error at index 686: 'Series' object is not callable
# Error at index 687: 'Series' object is not callable
# Error at index 688: 'Series' object is not callable
# Error at index 689: 'Series' object is not callable
# Error at index 690: 'Series' object is not callable
# Error at index 691: 'Series' object is not callable
# Error at index 692: 'Series' object is not callable
# Error at index 693: 'Series' object is not callable
# Error at index 694: 'Series' object is not callable
# Error at index 695: 'Series' object is not callable
# Error at index 696: 'Series' object is not callable
# Error at index 697: 'Series' object is not callable
# Error at index 698: 'Series' object is not callable
# Error at index 699: 'Series' object is not callable
# Error at index 700: 'Series' object is not callable
# Error at index 701: 'Series' object is not callable
# Error at index 702: 'Series' object is not callable
# Error at index 703: 'Series' object is not callable
# Error at index 704: 'Series' object is not callable
# Error at index 705: 'Series' object is not callable
# Error at index 706: 'Series' object is not callable
# Error at index 707: 'Series' object is not callable
# Error at index 708: 'Series' object is not callable
# Error at index 709: 'Series' object is not callable
# Error at index 710: 'Series' object is not callable
# Error at index 711: 'Series' object is not callable
# Error at index 712: 'Series' object is not callable
# Error at index 713: 'Series' object is not callable
# Error at index 714: 'Series' object is not callable
# Error at index 715: 'Series' object is not callable
# Error at index 716: 'Series' object is not callable
# Error at index 717: 'Series' object is not callable
# Error at index 718: 'Series' object is not callable
# Error at index 719: 'Series' object is not callable
# Error at index 720: 'Series' object is not callable
# Error at index 721: 'Series' object is not callable
# Error at index 722: 'Series' object is not callable
# Error at index 723: 'Series' object is not callable
# Error at index 724: 'Series' object is not callable
# Error at index 725: 'Series' object is not callable
# Error at index 726: 'Series' object is not callable
# Error at index 727: 'Series' object is not callable
# Error at index 728: 'Series' object is not callable
# Error at index 729: 'Series' object is not callable
# Error at index 730: 'Series' object is not callable
# Error at index 731: 'Series' object is not callable
# Error at index 732: 'Series' object is not callable
# Error at index 733: 'Series' object is not callable
# Error at index 734: 'Series' object is not callable
# Error at index 735: 'Series' object is not callable
# Error at index 736: 'Series' object is not callable
# Error at index 737: 'Series' object is not callable
# Error at index 738: 'Series' object is not callable
# Error at index 739: 'Series' object is not callable
# Error at index 740: 'Series' object is not callable
# Error at index 741: 'Series' object is not callable
# Error at index 742: 'Series' object is not callable
# Error at index 743: 'Series' object is not callable
# Error at index 744: 'Series' object is not callable
# Error at index 745: 'Series' object is not callable
# Error at index 746: 'Series' object is not callable
# Error at index 747: 'Series' object is not callable
# Error at index 748: 'Series' object is not callable
# Error at index 749: 'Series' object is not callable
# Error at index 750: 'Series' object is not callable
# Error at index 751: 'Series' object is not callable
# Error at index 752: 'Series' object is not callable
# Error at index 753: 'Series' object is not callable
# Error at index 754: 'Series' object is not callable
# Error at index 755: 'Series' object is not callable
# Error at index 756: 'Series' object is not callable
# Error at index 757: 'Series' object is not callable
# Error at index 758: 'Series' object is not callable
# Error at index 759: 'Series' object is not callable
# Error at index 760: 'Series' object is not callable
# Error at index 761: 'Series' object is not callable
# Error at index 762: 'Series' object is not callable
# Error at index 763: 'Series' object is not callable
# Error at index 764: 'Series' object is not callable
# Error at index 765: 'Series' object is not callable
# Error at index 766: 'Series' object is not callable
# Error at index 767: 'Series' object is not callable
# Error at index 768: 'Series' object is not callable
# Error at index 769: 'Series' object is not callable
# Error at index 770: 'Series' object is not callable
# Error at index 771: 'Series' object is not callable
# Error at index 772: 'Series' object is not callable
# Error at index 773: 'Series' object is not callable
# Error at index 774: 'Series' object is not callable
# Error at index 775: 'Series' object is not callable
# Error at index 776: 'Series' object is not callable
# Error at index 777: 'Series' object is not callable
# Error at index 778: 'Series' object is not callable
# Error at index 779: 'Series' object is not callable
# Error at index 780: 'Series' object is not callable
# Error at index 781: 'Series' object is not callable
# Error at index 782: 'Series' object is not callable
# Error at index 783: 'Series' object is not callable
# Error at index 784: 'Series' object is not callable
# Error at index 785: 'Series' object is not callable
# Error at index 786: 'Series' object is not callable
# Error at index 787: 'Series' object is not callable
# Error at index 788: 'Series' object is not callable
# Error at index 789: 'Series' object is not callable
# Error at index 790: 'Series' object is not callable
# Error at index 791: 'Series' object is not callable
# Error at index 792: 'Series' object is not callable
# Error at index 793: 'Series' object is not callable
# Error at index 794: 'Series' object is not callable
# Error at index 795: 'Series' object is not callable
# Error at index 796: 'Series' object is not callable
# Error at index 797: 'Series' object is not callable
# Error at index 798: 'Series' object is not callable
# Error at index 799: 'Series' object is not callable
# Error at index 800: 'Series' object is not callable
# Error at index 801: 'Series' object is not callable
# Error at index 802: 'Series' object is not callable
# Error at index 803: 'Series' object is not callable
# Error at index 804: 'Series' object is not callable
# Error at index 805: 'Series' object is not callable
# Error at index 806: 'Series' object is not callable
# Error at index 807: 'Series' object is not callable
# Error at index 808: 'Series' object is not callable
# Error at index 809: 'Series' object is not callable
# Error at index 810: 'Series' object is not callable
# Error at index 811: 'Series' object is not callable
# Error at index 812: 'Series' object is not callable
# Error at index 813: 'Series' object is not callable
# Error at index 814: 'Series' object is not callable
# Error at index 815: 'Series' object is not callable
# Error at index 816: 'Series' object is not callable
# Error at index 817: 'Series' object is not callable
# Error at index 818: 'Series' object is not callable
# Error at index 819: 'Series' object is not callable
# Error at index 820: 'Series' object is not callable
# Error at index 821: 'Series' object is not callable
# Error at index 822: 'Series' object is not callable
# Error at index 823: 'Series' object is not callable
# Error at index 824: 'Series' object is not callable
# Error at index 825: 'Series' object is not callable
# Error at index 826: 'Series' object is not callable
# Error at index 827: 'Series' object is not callable
# Error at index 828: 'Series' object is not callable
# Error at index 829: 'Series' object is not callable
# Error at index 830: 'Series' object is not callable
# Error at index 831: 'Series' object is not callable
# Error at index 832: 'Series' object is not callable
# Error at index 833: 'Series' object is not callable
# Error at index 834: 'Series' object is not callable
# Error at index 835: 'Series' object is not callable
# Error at index 836: 'Series' object is not callable
# Error at index 837: 'Series' object is not callable
# Error at index 838: 'Series' object is not callable
# Error at index 839: 'Series' object is not callable
# Error at index 840: 'Series' object is not callable
# Error at index 841: 'Series' object is not callable
# Error at index 842: 'Series' object is not callable
# Error at index 843: 'Series' object is not callable
# Error at index 844: 'Series' object is not callable
# Error at index 845: 'Series' object is not callable
# Error at index 846: 'Series' object is not callable
# Error at index 847: 'Series' object is not callable
# Error at index 848: 'Series' object is not callable
# Error at index 849: 'Series' object is not callable
# Error at index 850: 'Series' object is not callable
# Error at index 851: 'Series' object is not callable
# Error at index 852: 'Series' object is not callable
# Error at index 853: 'Series' object is not callable
# Error at index 854: 'Series' object is not callable
# Error at index 855: 'Series' object is not callable
# Error at index 856: 'Series' object is not callable
# Error at index 857: 'Series' object is not callable
# Error at index 858: 'Series' object is not callable
# Error at index 859: 'Series' object is not callable
# Error at index 860: 'Series' object is not callable
# Error at index 861: 'Series' object is not callable
# Error at index 862: 'Series' object is not callable
# Error at index 863: 'Series' object is not callable
# Error at index 864: 'Series' object is not callable
# Error at index 865: 'Series' object is not callable
# Error at index 866: 'Series' object is not callable
# Error at index 867: 'Series' object is not callable
# Error at index 868: 'Series' object is not callable
# Error at index 869: 'Series' object is not callable
# Error at index 870: 'Series' object is not callable
# Error at index 871: 'Series' object is not callable
# Error at index 872: 'Series' object is not callable
# Error at index 873: 'Series' object is not callable
# Error at index 874: 'Series' object is not callable
# Error at index 875: 'Series' object is not callable
# Error at index 876: 'Series' object is not callable
# Error at index 877: 'Series' object is not callable
# Error at index 878: 'Series' object is not callable
# Error at index 879: 'Series' object is not callable
# Error at index 880: 'Series' object is not callable
# Error at index 881: 'Series' object is not callable
# Error at index 882: 'Series' object is not callable
# Error at index 883: 'Series' object is not callable
# Error at index 884: 'Series' object is not callable
# Error at index 885: 'Series' object is not callable
# Error at index 886: 'Series' object is not callable
# Error at index 887: 'Series' object is not callable
# Error at index 888: 'Series' object is not callable
# Error at index 889: 'Series' object is not callable
# Error at index 890: 'Series' object is not callable
# Error at index 891: 'Series' object is not callable
# Error at index 892: 'Series' object is not callable
# Error at index 893: 'Series' object is not callable
# Error at index 894: 'Series' object is not callable
# Error at index 895: 'Series' object is not callable
# Error at index 896: 'Series' object is not callable
# Error at index 897: 'Series' object is not callable
# Error at index 898: 'Series' object is not callable
# Error at index 899: 'Series' object is not callable
# Error at index 900: 'Series' object is not callable
# Error at index 901: 'Series' object is not callable
# Error at index 902: 'Series' object is not callable
# Error at index 903: 'Series' object is not callable
# Error at index 904: 'Series' object is not callable
# Error at index 905: 'Series' object is not callable
# Error at index 906: 'Series' object is not callable
# Error at index 907: 'Series' object is not callable
# Error at index 908: 'Series' object is not callable
# Error at index 909: 'Series' object is not callable
# Error at index 910: 'Series' object is not callable
# Error at index 911: 'Series' object is not callable
# Error at index 912: 'Series' object is not callable
# Error at index 913: 'Series' object is not callable
# Error at index 914: 'Series' object is not callable
# Error at index 915: 'Series' object is not callable
# Error at index 916: 'Series' object is not callable
# Error at index 917: 'Series' object is not callable
# Error at index 918: 'Series' object is not callable
# Error at index 919: 'Series' object is not callable
# Error at index 920: 'Series' object is not callable
# Error at index 921: 'Series' object is not callable
# Error at index 922: 'Series' object is not callable
# Error at index 923: 'Series' object is not callable
# Error at index 924: 'Series' object is not callable
# Error at index 925: 'Series' object is not callable
# Error at index 926: 'Series' object is not callable
# Error at index 927: 'Series' object is not callable
# Error at index 928: 'Series' object is not callable
# Error at index 929: 'Series' object is not callable
# Error at index 930: 'Series' object is not callable
# Error at index 931: 'Series' object is not callable
# Error at index 932: 'Series' object is not callable
# Error at index 933: 'Series' object is not callable
# Error at index 934: 'Series' object is not callable
# Error at index 935: 'Series' object is not callable
# Error at index 936: 'Series' object is not callable
# Error at index 937: 'Series' object is not callable
# Error at index 938: 'Series' object is not callable
# Error at index 939: 'Series' object is not callable
# Error at index 940: 'Series' object is not callable
# Error at index 941: 'Series' object is not callable
# Error at index 942: 'Series' object is not callable
# Error at index 943: 'Series' object is not callable
# Error at index 944: 'Series' object is not callable
# Error at index 945: 'Series' object is not callable
# Error at index 946: 'Series' object is not callable
# Error at index 947: 'Series' object is not callable
# Error at index 948: 'Series' object is not callable
# Error at index 949: 'Series' object is not callable
# Error at index 950: 'Series' object is not callable
# Error at index 951: 'Series' object is not callable
# Error at index 952: 'Series' object is not callable
# Error at index 953: 'Series' object is not callable
# Error at index 954: 'Series' object is not callable
# Error at index 955: 'Series' object is not callable
# Error at index 956: 'Series' object is not callable
# Error at index 957: 'Series' object is not callable
# Error at index 958: 'Series' object is not callable
# Error at index 959: 'Series' object is not callable
# Error at index 960: 'Series' object is not callable
# Error at index 961: 'Series' object is not callable
# Error at index 962: 'Series' object is not callable
# Error at index 963: 'Series' object is not callable
# Error at index 964: 'Series' object is not callable
# Error at index 965: 'Series' object is not callable
# Error at index 966: 'Series' object is not callable
# Error at index 967: 'Series' object is not callable
# Error at index 968: 'Series' object is not callable
# Error at index 969: 'Series' object is not callable
# Error at index 970: 'Series' object is not callable
# Error at index 971: 'Series' object is not callable
# Error at index 972: 'Series' object is not callable
# Error at index 973: 'Series' object is not callable
# Error at index 974: 'Series' object is not callable
# Error at index 975: 'Series' object is not callable
# Error at index 976: 'Series' object is not callable
# Error at index 977: 'Series' object is not callable
# Error at index 978: 'Series' object is not callable
# Error at index 979: 'Series' object is not callable
# Error at index 980: 'Series' object is not callable
# Error at index 981: 'Series' object is not callable
# Error at index 982: 'Series' object is not callable
# Error at index 983: 'Series' object is not callable
# Error at index 984: 'Series' object is not callable
# Error at index 985: 'Series' object is not callable
# Error at index 986: 'Series' object is not callable
# Error at index 987: 'Series' object is not callable
# Error at index 988: 'Series' object is not callable
# Error at index 989: 'Series' object is not callable
# Error at index 990: 'Series' object is not callable
# Error at index 991: 'Series' object is not callable
# Error at index 992: 'Series' object is not callable
# Error at index 993: 'Series' object is not callable
# Error at index 994: 'Series' object is not callable
# Error at index 995: 'Series' object is not callable
# Error at index 996: 'Series' object is not callable
# Error at index 997: 'Series' object is not callable
# Error at index 998: 'Series' object is not callable
# Error at index 999: 'Series' object is not callable
# Error at index 1000: 'Series' object is not callable
# Error at index 1001: 'Series' object is not callable
# Error at index 1002: 'Series' object is not callable
# Error at index 1003: 'Series' object is not callable
# Error at index 1004: 'Series' object is not callable
# Error at index 1005: 'Series' object is not callable
# Error at index 1006: 'Series' object is not callable
# Error at index 1007: 'Series' object is not callable
# Error at index 1008: 'Series' object is not callable
# Error at index 1009: 'Series' object is not callable
# Error at index 1010: 'Series' object is not callable
# Error at index 1011: 'Series' object is not callable
# Error at index 1012: 'Series' object is not callable
# Error at index 1013: 'Series' object is not callable
# Error at index 1014: 'Series' object is not callable
# Error at index 1015: 'Series' object is not callable
# Error at index 1016: 'Series' object is not callable
# Error at index 1017: 'Series' object is not callable
# Error at index 1018: 'Series' object is not callable
# Error at index 1019: 'Series' object is not callable
# Error at index 1020: 'Series' object is not callable
# Error at index 1021: 'Series' object is not callable
# Error at index 1022: 'Series' object is not callable
# Error at index 1023: 'Series' object is not callable
# Error at index 1024: 'Series' object is not callable
# Error at index 1025: 'Series' object is not callable
# Error at index 1026: 'Series' object is not callable
# Error at index 1027: 'Series' object is not callable
# Error at index 1028: 'Series' object is not callable
# Error at index 1029: 'Series' object is not callable
# Error at index 1030: 'Series' object is not callable
# Error at index 1031: 'Series' object is not callable
# Error at index 1032: 'Series' object is not callable
# Error at index 1033: 'Series' object is not callable
# Error at index 1034: 'Series' object is not callable
# Error at index 1035: 'Series' object is not callable
# Error at index 1036: 'Series' object is not callable
# Error at index 1037: 'Series' object is not callable
# Error at index 1038: 'Series' object is not callable
# Error at index 1039: 'Series' object is not callable
# Error at index 1040: 'Series' object is not callable
# Error at index 1041: 'Series' object is not callable
# Error at index 1042: 'Series' object is not callable
# Error at index 1043: 'Series' object is not callable
# Error at index 1044: 'Series' object is not callable
# Error at index 1045: 'Series' object is not callable
# Error at index 1046: 'Series' object is not callable
# Error at index 1047: 'Series' object is not callable
# Error at index 1048: 'Series' object is not callable
# Error at index 1049: 'Series' object is not callable
# Error at index 1050: 'Series' object is not callable
# Error at index 1051: 'Series' object is not callable
# Error at index 1052: 'Series' object is not callable
# Error at index 1053: 'Series' object is not callable
# Error at index 1054: 'Series' object is not callable
# Error at index 1055: 'Series' object is not callable
# Error at index 1056: 'Series' object is not callable
# Error at index 1057: 'Series' object is not callable
# Error at index 1058: 'Series' object is not callable
# Error at index 1059: 'Series' object is not callable
# Error at index 1060: 'Series' object is not callable
# Error at index 1061: 'Series' object is not callable
# Error at index 1062: 'Series' object is not callable
# Error at index 1063: 'Series' object is not callable
# Error at index 1064: 'Series' object is not callable
# Error at index 1065: 'Series' object is not callable
# Error at index 1066: 'Series' object is not callable
# Error at index 1067: 'Series' object is not callable
# Error at index 1068: 'Series' object is not callable
# Error at index 1069: 'Series' object is not callable
# Error at index 1070: 'Series' object is not callable
# Error at index 1071: 'Series' object is not callable
# Error at index 1072: 'Series' object is not callable
# Error at index 1073: 'Series' object is not callable
# Error at index 1074: 'Series' object is not callable
# Error at index 1075: 'Series' object is not callable
# Error at index 1076: 'Series' object is not callable
# Error at index 1077: 'Series' object is not callable
# Error at index 1078: 'Series' object is not callable
# Error at index 1079: 'Series' object is not callable
# Error at index 1080: 'Series' object is not callable
# Error at index 1081: 'Series' object is not callable
# Error at index 1082: 'Series' object is not callable
# Error at index 1083: 'Series' object is not callable
# Error at index 1084: 'Series' object is not callable
# Error at index 1085: 'Series' object is not callable
# Error at index 1086: 'Series' object is not callable
# Error at index 1087: 'Series' object is not callable
# Error at index 1088: 'Series' object is not callable
# Error at index 1089: 'Series' object is not callable
# Error at index 1090: 'Series' object is not callable
# Error at index 1091: 'Series' object is not callable
# Error at index 1092: 'Series' object is not callable
# Error at index 1093: 'Series' object is not callable
# Error at index 1094: 'Series' object is not callable
# Error at index 1095: 'Series' object is not callable
# Error at index 1096: 'Series' object is not callable
# Error at index 1097: 'Series' object is not callable
# Error at index 1098: 'Series' object is not callable
# Error at index 1099: 'Series' object is not callable
# Error at index 1100: 'Series' object is not callable
# Error at index 1101: 'Series' object is not callable
# Error at index 1102: 'Series' object is not callable
# Error at index 1103: 'Series' object is not callable
# Error at index 1104: 'Series' object is not callable
# Error at index 1105: 'Series' object is not callable
# Error at index 1106: 'Series' object is not callable
# Error at index 1107: 'Series' object is not callable
# Error at index 19: 'Series' object is not callable
# Error at index 20: 'Series' object is not callable
# Error at index 21: 'Series' object is not callable
# Error at index 22: 'Series' object is not callable
# Error at index 23: 'Series' object is not callable
# Error at index 24: 'Series' object is not callable
# Error at index 25: 'Series' object is not callable
# Error at index 26: 'Series' object is not callable
# C:\Users\negul\AppData\Local\Temp\ipykernel_32584\3124971848.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   values = pd.Series(index=data['log_return'].index)
# Error at index 27: 'Series' object is not callable
# Error at index 28: 'Series' object is not callable
# Error at index 29: 'Series' object is not callable
# Error at index 30: 'Series' object is not callable
# Error at index 31: 'Series' object is not callable
# Error at index 32: 'Series' object is not callable
# Error at index 33: 'Series' object is not callable
# Error at index 34: 'Series' object is not callable
# Error at index 35: 'Series' object is not callable
# Error at index 36: 'Series' object is not callable
# Error at index 37: 'Series' object is not callable
# Error at index 38: 'Series' object is not callable
# Error at index 39: 'Series' object is not callable
# Error at index 40: 'Series' object is not callable
# Error at index 41: 'Series' object is not callable
# Error at index 42: 'Series' object is not callable
# Error at index 43: 'Series' object is not callable
# Error at index 44: 'Series' object is not callable
# Error at index 45: 'Series' object is not callable
# Error at index 46: 'Series' object is not callable
# Error at index 47: 'Series' object is not callable
# Error at index 48: 'Series' object is not callable
# Error at index 49: 'Series' object is not callable
# Error at index 50: 'Series' object is not callable
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [279], in <cell line: 7>()
#      14 try:
#      15     am = arch_model(X.dropna(), mean='Zero', vol='Garch', p=1, o=0, q=1, dist='Normal', rescale=False)
# ---> 16     res = am.fit(update_freq=0, disp='off')
#      17     forecast = res.forecast(horizon=1)
#      18     s2 = forecast.variance.values[-1, -1]
#
# File c:\Python310\lib\site-packages\arch\univariate\base.py:748, in ARCHModel.fit(self, update_freq, disp, starting_values, cov_type, show_warning, first_obs, last_obs, tol, options, backcast)
#     742 with warnings.catch_warnings():
#     743     warnings.filterwarnings(
#     744         "ignore",
#     745         "Values in x were outside bounds during a minimize step",
#     746         RuntimeWarning,
#     747     )
# --> 748     opt = minimize(
#     749         func,
#     750         sv,
#     751         args=args,
#     752         method="SLSQP",
#     753         bounds=bounds,
#     754         constraints=ineq_constraints,
#     755         tol=tol,
#     756         callback=_callback,
#     757         options=options,
#     758     )
#     760 if show_warning:
#     761     warnings.filterwarnings("always", "", ConvergenceWarning)
#
# File c:\Python310\lib\site-packages\scipy\optimize\_minimize.py:690, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     687     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     688                             **options)
#     689 elif meth == 'slsqp':
# --> 690     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     691                           constraints, callback=callback, **options)
#     692 elif meth == 'trust-constr':
#     693     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     694                                        bounds, constraints,
#     695                                        callback=callback, **options)
#
# File c:\Python310\lib\site-packages\scipy\optimize\_slsqp_py.py:374, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     371     xu[infbnd[:, 1]] = np.nan
#     373 # ScalarFunction provides function and gradient evaluation
# --> 374 sf = _prepare_scalar_function(func, x, jac=jac, args=args, epsilon=eps,
#     375                               finite_diff_rel_step=finite_diff_rel_step,
#     376                               bounds=new_bounds)
#     377 # gh11403 SLSQP sometimes exceeds bounds by 1 or 2 ULP, make sure this
#     378 # doesn't get sent to the func/grad evaluator.
#     379 wrapped_fun = _clip_x_for_func(sf.fun, new_bounds)
#
# File c:\Python310\lib\site-packages\scipy\optimize\_optimize.py:263, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     bounds = (-np.inf, np.inf)
#     261 # ScalarFunction caches. Reuse of fun(x) during grad
#     262 # calculation reduces overall function evaluations.
# --> 263 sf = ScalarFunction(fun, x0, args, grad, hess,
#     264                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     266 return sf
#
# File c:\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:177, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     173         self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                                    **finite_diff_options)
#     176 self._update_grad_impl = update_grad
# --> 177 self._update_grad()
#     179 # Hessian Evaluation
#     180 if callable(hess):
#
# File c:\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File c:\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File c:\Python310\lib\site-packages\scipy\optimize\_numdiff.py:484, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     481     h = _compute_absolute_step(rel_step, x0, f0, method)
#     482 else:
#     483     # user specifies an absolute step
# --> 484     sign_x0 = (x0 >= 0).astype(float) * 2 - 1
#     485     h = abs_step
#     487     # cannot have a zero step. This might happen if x0 is very large
#     488     # or small. In which case fall back to relative step.
#
# KeyboardInterrupt:

# %%
Var95 = np.zeros(len(data))
Var99 = np.zeros(len(data))
for j in range (0,len(data)):
    Var95[j] = mean_VaR95
    Var99[j] = mean_VaR99

data['VaR95%'] = Var95
data['VaR99%'] = Var99

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR95%']
data['violation99'] = data['log_return'] < data['VaR99%']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")
# Out:
# Liczba naruszeń VaR95%: 68
# Liczba naruszeń VaR99%: 20

# %% [markdown]
# ### c. Monte Carlo method with selected distribution/process

# %%
num_simulations = 500
mc_simulations = 3

plt.figure(figsize=[15,8])
plt.title('VaR95% oraz VaR 99% przy obliczeniu metodą Monte Carlo z rozkładem T-studenta', color = 'pink')
plt.plot(data['Data'], data['log_return'])

# Przykład dat, które są późniejsze od początku DataFrame
dates = pd.date_range(start="2024-04-20", periods=num_simulations, freq='D')
df = {
    'date': dates,
}
df = pd.DataFrame(df)
df.set_index('date', inplace=True)

colors = ['red', 'black']
labels = ['VaR95%', 'VaR99%']
Values_var = []
for alpha,color,label in zip(alphas, colors, labels):
    VaR = np.zeros(mc_simulations)
    for i in range (0,mc_simulations):
        dane = stats.t.rvs(params_t[0], size=num_simulations, loc=params_t[1], scale=params_t[2])
        df['MC'] = dane
        plt.scatter(dates,df['MC'])
        VaR[i] = df['MC'].quantile(alpha)
    Values_var.append(np.mean(VaR))
    
print(Values_var[0], Values_var[1])

Var95 = np.zeros(num_simulations)
Var99 = np.zeros(num_simulations)
for j in range (0,num_simulations):
    Var95[j] = np.mean(Values_var[0])
    Var99[j] = np.mean(Values_var[1])

df['VaR_95'] = Var95
df['VaR_99'] = Var99
  
Var95 = np.zeros(len(data))
Var99 = np.zeros(len(data))
for j in range (0,len(data)):
    Var95[j] = np.mean(Values_var[0])
    Var99[j] = np.mean(Values_var[1])

data['VaR_95'] = Var95
data['VaR_99'] = Var99

plt.plot(df['VaR_95'], label = 'VaR95%', color = 'red')
plt.plot(df['VaR_99'], label = 'VaR99%', color = 'black')
plt.plot(data['Data'], data['VaR_95'], color = 'red')
plt.plot(data['Data'],data['VaR_99'], color = 'black')

# Obliczenie naruszeń VaR
data['violation95'] = data['log_return'] < data['VaR_95']
data['violation99'] = data['log_return'] < data['VaR_99']
# Podsumowanie naruszeń
total_violations95 = data['violation95'].sum()
total_violations99 = data['violation99'].sum()

print(f"Liczba naruszeń VaR95%: {total_violations95}")
print(f"Liczba naruszeń VaR99%: {total_violations99}")


plt.xlabel('Data', color = 'pink')
plt.ylabel('Zwroty logarytmiczne', color = 'pink')
plt.xticks(color = 'pink')
plt.yticks(color = 'pink')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('MC.png')
# Out:
# -0.007568238580480803 -0.011032258621858268
# Liczba naruszeń VaR95%: 61
# Liczba naruszeń VaR99%: 15

# %%
from scipy.stats import t
num_simulations = 10000
# Generowanie symulowanych zwrotów
simulated_returns = t.rvs(params_t[0], size=num_simulations, loc=params_t[1], scale=params_t[2])

# Obliczenie VaR95%
VaR_95 = np.percentile(simulated_returns, 5)

print("Obliczony VaR95% przy użyciu rozkładu t-Studenta wynosi:", VaR_95)
# Out:
# Obliczony VaR95% przy użyciu rozkładu t-Studenta wynosi: -0.0075681811285798605

# %%
# Parametry
mean = params_t[1]
volatility = params_t[2] # Zmienność (odchylenie standardowe przyrostów)
steps = 260  # Liczba kroków (dni handlowych w roku)
simulations = 100000  # Liczba symulacji

# Generowanie trajektorii ruchu Browna
daily_returns = np.random.normal(mean, volatility, (steps, simulations))
price_paths = np.cumprod(1 + daily_returns, axis=0)  # Ścieżki cenowe

# Obliczenie końcowych cen i VaR95%
final_prices = price_paths[-1, :]
VaR_95_brown = np.percentile(final_prices, 5)
print("Obliczony VaR95% dla ruchu Browna wynosi:", VaR_95_brown)
# Out:
# Obliczony VaR95% dla ruchu Browna wynosi: 0.8865737684098978

# %%
# Obliczenie VaR95% i VaR99%
VaR_95 = np.percentile(returns, 5)
VaR_99 = np.percentile(returns, 1)

# Przygotowanie danych do testowania wstecznego
actual_losses = -1 * returns  # Zakładamy, że straty to zwroty ujemne

# Liczenie naruszeń
violations_95 = sum(actual_losses < VaR_95)
violations_99 = sum(actual_losses < VaR_99)

# Wydruk wyników testowania
print(f"Violations for VaR95%: {violations_95}")
print(f"Violations for VaR99%: {violations_99}")
# Out:
# Violations for VaR95%: 58
# Violations for VaR99%: 9
